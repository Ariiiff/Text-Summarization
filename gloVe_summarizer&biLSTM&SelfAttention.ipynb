# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariiiff/Text-Summarization/blob/main/gloVe_summarizer%26biLSTM%26SelfAttention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==1.15
# import keras==2.2.4
import numpy as np  
import pandas as pd 
import re           
import os
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# !pip install wget
import wget
import nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==1.15 (from versions: 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.12.0)
# ERROR: No matching distribution found for tensorflow-gpu==1.15
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=fb7afeddc9880f5822880d496777fc26b1e9c12f54b38b89bd845435d75fdbab
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
# read text file into pandas DataFrame
articles = pd.read_table("/content/gdrive/MyDrive/Bangla_News_Article_Dataset/article.txt")
# display DataFrame
print(articles.iloc[100])

# read text file into pandas DataFrame
summaries = pd.read_table("/content/gdrive/MyDrive/Bangla_News_Article_Dataset/summary.txt")
# display DataFrame
print(summaries.iloc[100])
# Out:
# স্ট্যান্ডার্ড চার্টার্ড ব্যাংকের নতুন প্রধান নির্বাহী কর্মকর্তা হিসেবে দায়িত্ব পেয়েছেন আবরার এ আনোয়ার।    বঙ্গবন্ধুর স্বদেশ প্রত্যাবর্তন দিবস উপলক্ষে সোমবার রাজধানীর সোহরাওয়ার্দী উদ্যানে সমাবেশ করতে পুলিশের অনুমতি পেয়েছে ক্ষমতাসীন আওয়ামী লীগ।
# Name: 100, dtype: object
# স্ট্যান্ডার্ড চার্টার্ডের নতুন সিইও আবরার    আওয়ামী লীগকে ঢাকায় সমাবেশের অনুমতি পুলিশের
# Name: 100, dtype: object

# %%
dataframe = pd.concat([articles, summaries], axis=1, sort=False)
dataframe.columns = ['article', 'summary']

# %%
dataframe.tail(5)
# Out:
#                                                                                                                                                                                                        article  \
# 19090  মাঝারি থেকে দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক্ষার কথা জানানোর পর উত্তর কোরিয়া ফের জাতিসংঘ ও যুক্তরাষ্ট্রের হুঁশিয়ারি উপেক্ষা করে যে কোনও সময়, যে কোনও স্থান থেকে এ ধরনের পরীক্ষা চালিয়ে যাওয়ার হুমক...
# 19091                        বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের ১৫৬তম ও জাতীয় কবি কাজী নজরুল ইসলামের ১১৮তম জন্মজয়ন্তী উপলক্ষে আরব আমিরাতের আবুধাবিতে বাংলাদেশ দূতাবাস আলোচনাসভা ও সাংস্কৃতিক অনুষ্ঠানের আয়োজন করেছে।
# 19092                                 এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্থ রাউন্ডে নিজেদের বিভাগে ড্র করেছেন গ্র্যান্ডমাস্টার এনামুল হোসেন রাজীব ও মহিলা ইন্টারন্যাশনাল মাস্টার শামীমা আক্তার লিজা।
# 19093                                                            শাখার পূর্ণাঙ্গ কমিটি করতে না পারার জন্য বড় ভাইদের দাবির সমন্বয় করতে না পারাকে কারণ দেখিয়েছেন চট্টগ্রাম বিভাগের কয়েকটি জেলার ছাত্রলীগ নেতারা।
# 19094                                                                                         বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানমন্ত্রী শেখ হাসিনার হাতে অনুদানের ১৩৬ কোটি ২০ লাখ টাকা তুলে দিয়েছে।
#
#                                                          summary
# 19090   যেকোনও সময় ফের ক্ষেপণাস্ত্র পরীক্ষার হুমকি উত্তর কোরিয়ার
# 19091                    আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19092                                     চীনে রাজীব ও লিজার ড্র
# 19093                      বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19094  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ কোটি টাকা অনুদান হস্তান্তর

# %%
new_df = dataframe.dropna()

# %%
new_df
# Out:
#                                                                                                                                                                                                        article  \
# 0                                                                               রাজধানী থেকে চামড়া শিল্পগুলো সাভারে স্থানান্তরে সিইটিপি ছাড়া সরকার সব কাজ শেষ করেছে বলে জানিয়েছেন শিল্পমন্ত্রী আমির হোসেন আমু।
# 1                                                                                                         দেশীয় শিল্প বিকাশে সরকারের সব ধরনের উদ্যোগ অব্যাহত রাখার আশ্বাস দিয়েছেন শিল্পমন্ত্রী আমির হোসেন আমু।
# 2                                                                                                                একীভূত হতে চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন সেবাদাতা দুই প্রতিষ্ঠান এখানেই ডটকম এবং ওএলএক্স।
# 3                                                     যাত্রীবাহী একটি বাসে আগুন দেওয়ার আধা ঘণ্টার মধ্যে এই ঘটনায় জড়িত অভিযোগে নড়াইলের পৌর মেয়র ও জেলা বিএনপির সাংগঠনিক সম্পাদক জুলফিকার আলীকে আটক করেছে পুলিশ।
# 4                                                                                             অবরোধে বাস পোড়ানোর অভিযোগে মাগুরা জেলা বিএনপি সভাপতি কবির মুরাদসহ ৪২ নেতাকর্মীর বিরুদ্ধে একটি মামলা করেছে পুলিশ।
# ...                                                                                                                                                                                                        ...
# 19090  মাঝারি থেকে দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক্ষার কথা জানানোর পর উত্তর কোরিয়া ফের জাতিসংঘ ও যুক্তরাষ্ট্রের হুঁশিয়ারি উপেক্ষা করে যে কোনও সময়, যে কোনও স্থান থেকে এ ধরনের পরীক্ষা চালিয়ে যাওয়ার হুমক...
# 19091                        বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের ১৫৬তম ও জাতীয় কবি কাজী নজরুল ইসলামের ১১৮তম জন্মজয়ন্তী উপলক্ষে আরব আমিরাতের আবুধাবিতে বাংলাদেশ দূতাবাস আলোচনাসভা ও সাংস্কৃতিক অনুষ্ঠানের আয়োজন করেছে।
# 19092                                 এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্থ রাউন্ডে নিজেদের বিভাগে ড্র করেছেন গ্র্যান্ডমাস্টার এনামুল হোসেন রাজীব ও মহিলা ইন্টারন্যাশনাল মাস্টার শামীমা আক্তার লিজা।
# 19093                                                            শাখার পূর্ণাঙ্গ কমিটি করতে না পারার জন্য বড় ভাইদের দাবির সমন্বয় করতে না পারাকে কারণ দেখিয়েছেন চট্টগ্রাম বিভাগের কয়েকটি জেলার ছাত্রলীগ নেতারা।
# 19094                                                                                         বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানমন্ত্রী শেখ হাসিনার হাতে অনুদানের ১৩৬ কোটি ২০ লাখ টাকা তুলে দিয়েছে।
#
#                                                          summary
# 0            মার্চের মধ্যে সাভারে চামড়া শিল্পের সিইটিপি: মন্ত্রী
# 1                                   ওয়ালটন কারখানায় শিল্পমন্ত্রী
# 2                                একীভূত হচ্ছে এখানেই ডটকমওএলএক্স
# 3                          বাসে আগুন: নড়াইলের পৌর মেয়র গ্রেপ্তার
# 4                   মাগুরায় বাসে আগুন: বিএনপি নেতাদের নামে মামলা
# ...                                                          ...
# 19090   যেকোনও সময় ফের ক্ষেপণাস্ত্র পরীক্ষার হুমকি উত্তর কোরিয়ার
# 19091                    আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19092                                     চীনে রাজীব ও লিজার ড্র
# 19093                      বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19094  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ কোটি টাকা অনুদান হস্তান্তর
#
# [19095 rows x 2 columns]

# %%
def text_to_word_list(text):
    text = text.split()
    return text

def replace_strings(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           u"\u00C0-\u017F"          #latin
                           u"\u2000-\u206F"          #generalPunctuations
                               
                           "]+", flags=re.UNICODE)
    english_pattern=re.compile('[a-zA-Z0-9]+', flags=re.I)
    #latin_pattern=re.compile('[A-Za-z\u00C0-\u00D6\u00D8-\u00f6\u00f8-\u00ff\s]*',)
    
    text=emoji_pattern.sub(r'', text)
    text=english_pattern.sub(r'', text)

    return text

def remove_punctuations(my_str):
    # define punctuation
    punctuations = '''````£|¢|Ñ+-*/=EROero৳০১২৩৪৫৬৭৮৯012–34567•89।!()-[]{};:'"“\’,<>./?@#$%^&*_~‘—॥”‰🤣⚽️✌�￰৷￰'''
    
    no_punct = ""
    for char in my_str:
        if char not in punctuations:
            no_punct = no_punct + char

    # display the unpunctuated string
    return no_punct



def joining(text):
    out=' '.join(text)
    return out

def preprocessing(text):
    out=remove_punctuations(replace_strings(text))
    return out

# %%
clean_articles = []
for art in new_df["article"] : 
  clean_articles.append(preprocessing(art))


clean_summaries = []
for sum in new_df["summary"] : 
  clean_summaries.append(preprocessing(sum))

# %%
len(clean_summaries)
# Out:
# 19095

# %%
data1 = pd.read_excel('/content/gdrive/MyDrive/Bangla_News_Article_Dataset/stopwords_bangla.xlsx')
stopwords = data1['words'].tolist()

# %%
def stopwordRemoval(text):    
    x=str(text)
    l=x.split() 

    stm=[elem for elem in l if elem not in stopwords] 
    
    out=' '.join(stm) 

    return str(out)

# %%
clean_article = []
for art in clean_articles : 
  clean_article.append(stopwordRemoval(art))


clean_summary = []
for sum in new_df["summary"] : 
  clean_summary.append(stopwordRemoval(sum))

# %%
clean_article[: 10]
# Out:
# ['রাজধানী চামড়া শিল্পগুলো সাভারে স্থানান্তরে সিইটিপি সরকার জানিয়েছেন শিল্পমন্ত্রী আমির হোসেন আমু',
#  'দেশীয় শিল্প বিকাশে সরকারের ধরনের উদ্যোগ অব্যাহত রাখার আশ্বাস শিল্পমন্ত্রী আমির হোসেন আমু',
#  'একীভূত চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন সেবাদাতা প্রতিষ্ঠান ডটকম ওএলএক্স',
#  'যাত্রীবাহী বাসে আগুন আধা ঘণ্টার ঘটনায় জড়িত অভিযোগে নড়াইলের পৌর মেয়র জেলা বিএনপির সাংগঠনিক সম্পাদক জুলফিকার আলীকে আটক পুলিশ',
#  'অবরোধে বাস পোড়ানোর অভিযোগে মাগুরা জেলা বিএনপি সভাপতি কবির মুরাদসহ নেতাকর্মীর বিরুদ্ধে পুলিশ',
#  'তথ্য প্রযুক্তি দক্ষ জনশক্তি গড়ে তুলতে ইন্ডাস্ট্রি একাডেমির যৌথ উদ্যোগে গঠিত বেসিস স্টুডেন্টস ফোরাম',
#  'শরীয়তপুরের নড়িয়া উপজেলায় ভুল চিকিৎসায় শিশু মৃত্যুর অভিযোগে ক্লিনিকে ভাঙচুর',
#  'জাতীয় চলচ্চিত্র পুরস্কার একুশে পদকজয়ী নির্মাতা চাষী নজরুল ইসলাম রাজধানীর হাসপাতালে চিকিৎসাধীন অবস্থায় মারা গেছেন',
#  'বিএনপির লাগাতার অবরোধের রাজধানীর ফকিরাপুলে পুলিশ বহনকারী বাসে ট্রাকের ধাক্কায় নারী পুলিশ নিহত আহত পুলিশের নারী',
#  'রাজধানীর মোহাম্মদপুরের বস্তিতে আগুনে দগ্ধ বছরের শিশুর মৃত্যু']

# %%
new_df['clean_article'] = clean_article
new_df['clean_summary'] = clean_summary

# %%
new_df.tail(5)
# Out:
#                                                                                                                                                                                                        article  \
# 19090  মাঝারি থেকে দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক্ষার কথা জানানোর পর উত্তর কোরিয়া ফের জাতিসংঘ ও যুক্তরাষ্ট্রের হুঁশিয়ারি উপেক্ষা করে যে কোনও সময়, যে কোনও স্থান থেকে এ ধরনের পরীক্ষা চালিয়ে যাওয়ার হুমক...
# 19091                        বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের ১৫৬তম ও জাতীয় কবি কাজী নজরুল ইসলামের ১১৮তম জন্মজয়ন্তী উপলক্ষে আরব আমিরাতের আবুধাবিতে বাংলাদেশ দূতাবাস আলোচনাসভা ও সাংস্কৃতিক অনুষ্ঠানের আয়োজন করেছে।
# 19092                                 এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্থ রাউন্ডে নিজেদের বিভাগে ড্র করেছেন গ্র্যান্ডমাস্টার এনামুল হোসেন রাজীব ও মহিলা ইন্টারন্যাশনাল মাস্টার শামীমা আক্তার লিজা।
# 19093                                                            শাখার পূর্ণাঙ্গ কমিটি করতে না পারার জন্য বড় ভাইদের দাবির সমন্বয় করতে না পারাকে কারণ দেখিয়েছেন চট্টগ্রাম বিভাগের কয়েকটি জেলার ছাত্রলীগ নেতারা।
# 19094                                                                                         বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানমন্ত্রী শেখ হাসিনার হাতে অনুদানের ১৩৬ কোটি ২০ লাখ টাকা তুলে দিয়েছে।
#
#                                                          summary  \
# 19090   যেকোনও সময় ফের ক্ষেপণাস্ত্র পরীক্ষার হুমকি উত্তর কোরিয়ার
# 19091                    আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19092                                     চীনে রাজীব ও লিজার ড্র
# 19093                      বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19094  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ কোটি টাকা অনুদান হস্তান্তর
#
#                                                                                                                                                           clean_article  \
# 19090                    মাঝারি দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক্ষার কথা জানানোর কোরিয়া জাতিসংঘ যুক্তরাষ্ট্রের হুঁশিয়ারি উপেক্ষা সময় স্থান ধরনের পরীক্ষা চালিয়ে হুমকি
# 19091  বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের তম জাতীয় কবি কাজী নজরুল ইসলামের তম জন্মজয়ন্তী উপলক্ষে আরব আমিরাতের আবুধাবিতে বাংলাদেশ দূতাবাস আলোচনাসভা সাংস্কৃতিক অনুষ্ঠানের আয়োজন
# 19092            এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্থ রাউন্ডে বিভাগে ড্র গ্র্যান্ডমাস্টার এনামুল হোসেন রাজীব মহিলা ইন্টারন্যাশনাল মাস্টার শামীমা আক্তার লিজা
# 19093                                                 শাখার পূর্ণাঙ্গ কমিটি না পারার বড় ভাইদের দাবির সমন্বয় না পারাকে দেখিয়েছেন চট্টগ্রাম বিভাগের জেলার ছাত্রলীগ নেতারা
# 19094                                                                           বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানমন্ত্রী শেখ হাসিনার হাতে অনুদানের লাখ টাকা
#
#                                               clean_summary
# 19090        যেকোনও সময় ক্ষেপণাস্ত্র পরীক্ষার হুমকি কোরিয়ার
# 19091               আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19092                                  চীনে রাজীব লিজার ড্র
# 19093                 বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19094  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ টাকা অনুদান হস্তান্তর

# %%
new_df['clean_summary'] = new_df['clean_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
for i in range(5):
    print("Article:",new_df['clean_article'][i])
    print("Summary:",new_df['clean_summary'][i])
    print("\n")
# Out:
# Article: রাজধানী চামড়া শিল্পগুলো সাভারে স্থানান্তরে সিইটিপি সরকার জানিয়েছেন শিল্পমন্ত্রী আমির হোসেন আমু
# Summary: _START_ মার্চের সাভারে চামড়া শিল্পের সিইটিপি: মন্ত্রী _END_
#
#
# Article: দেশীয় শিল্প বিকাশে সরকারের ধরনের উদ্যোগ অব্যাহত রাখার আশ্বাস শিল্পমন্ত্রী আমির হোসেন আমু
# Summary: _START_ ওয়ালটন কারখানায় শিল্পমন্ত্রী _END_
#
#
# Article: একীভূত চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন সেবাদাতা প্রতিষ্ঠান ডটকম ওএলএক্স
# Summary: _START_ একীভূত ডটকমওএলএক্স _END_
#
#
# Article: যাত্রীবাহী বাসে আগুন আধা ঘণ্টার ঘটনায় জড়িত অভিযোগে নড়াইলের পৌর মেয়র জেলা বিএনপির সাংগঠনিক সম্পাদক জুলফিকার আলীকে আটক পুলিশ
# Summary: _START_ বাসে আগুন: নড়াইলের পৌর মেয়র গ্রেপ্তার _END_
#
#
# Article: অবরোধে বাস পোড়ানোর অভিযোগে মাগুরা জেলা বিএনপি সভাপতি কবির মুরাদসহ নেতাকর্মীর বিরুদ্ধে পুলিশ
# Summary: _START_ মাগুরায় বাসে আগুন: বিএনপি নেতাদের নামে _END_

# %%
new_df = new_df.drop(labels=4289, axis=0)

# %%
new_df.iloc[4287: 4390]
# Out:
#                                                                                                                                                                                                       article  \
# 4287                            গোল্ড কাপ জয়ের লক্ষ্য পূরণের দারুণ সম্ভাবনা তৈরি করে শেষ পর্যন্ত না পারার ব্যর্থতায় হতাশ লোডভিক ডি ক্রুইফ। বাংলাদেশ কোচ জানান, তার নিজের এবং দলের জন্য এই হার ভীষণ বেদনাদায়ক।
# 4288  স্বাগতিক বাংলাদেশকে হারিয়ে বঙ্গবন্ধু গোল্ড কাপ জয়ের পর শিষ্যদের হার না মানসিকতার প্রশংসা করেন মালয়েশিয়া কোচ রাজীব ইসমাইল। গোল্ড কাপ জয়ের ফলে এএফসি অনূর্ধ্ব২৩ চ্যাম্পিয়নশিপের প্রস্তুতিও ভালো হলো বল...
# 4290                                                                                     জনগণের কষ্টার্জিত অর্থের অপচয় কঠোরভাবে নিয়ন্ত্রণ করতে সংশ্লিষ্টদের প্রতি আহ্বান জানিয়েছেন রাষ্ট্রপতি মো আবদুল হামিদ।
# 4291  ডোয়াইন ব্র্যাভো ও কাইরন পোলার্ডের না থাকাটা দলের জন্য বড় ক্ষতি হিসেবে মানছেন ওয়েস্ট ইন্ডিজের অধিনায়ক জেসন হোল্ডার। আর এই দুজনকে বিশ্বকাপ দলে না নেয়ার নির্বাচকদের সিদ্ধান্তে নিজের অসন্তোষও লুকোনোর ...
# 4292                                                                                            রাষ্ট্রপতি মো আবদুল হামিদের সঙ্গে সৌজন্য সাক্ষাৎ করেছে মালদ্বীপের ন্যাশনাল ডিফেন্স ফোর্সের একটি প্রতিনিধি দল।
# ...                                                                                                                                                                                                       ...
# 4386                                                                                 ধর্মীয় অনুভূতিতে আঘাত দেওয়ার এক মামলায় ঠাকুরগাঁওয়ের আদালতে হাজির হয়ে জামিন নিয়েছেন দৈনিক প্রথম আলোর সম্পাদক মতিউর রহমান।
# 4387                      তথ্য ও যোগাযোগ প্রযুক্তি খাতে বাংলাদেশের বৈদেশিক আয়ের পরিমাণ শিগগির তৈরি পোশাক খাতকে ছাড়িয়ে যাওয়ার আশা করছেন প্রধানমন্ত্রীর তথ্য ও যোগাযোগ প্রযুক্তি বিষয়ক উপদেষ্টা সজীব ওয়াজেদ জয়।
# 4388                                                                                                                                           ব্যাংকিং খাতে খেলাপি ঋণ কমেছে বলে দাবি করেছে কেন্দ্রীয় ব্যাংক।
# 4389                                                                                                           সাত দিন মৃত্যুর সঙ্গে লড়াই করে হার মানলেন রাজশাহীতে পেট্রোল বোমায় দগ্ধ এক ট্রাক চালকের সহকারী।
# 4390                                                                        সৌদি আরবে কর্মী পাঠাতে নিবন্ধন করা হবে এমন ধারণার ভিত্তিতে চট্টগ্রামের জেলা কর্মসংস্থান ও জনশক্তি কার্যালয়ে ভিড় জমায় কয়েকশ মানুষ।
#
#                                                              summary  \
# 4287                                     ক্রুইফের কাছে বেদনাদায়ক হার
# 4288                         শিষ্যদের প্রশংসায় পঞ্চমুখ মালয়েশিয়া কোচ
# 4290                    অপচয় কঠোরভাবে নিয়ন্ত্রণ করতে হবে: রাষ্ট্রপতি
# 4291                        ব্র্যাভো ও পোলার্ড না থাকাটা বিরাট ক্ষতি
# 4292  রাষ্ট্রপতির সঙ্গে মালদ্বীপের প্রতিরক্ষা প্রতিনিধি দলের সাক্ষাৎ
# ...                                                              ...
# 4386                                   জামিন পেলেন প্রথম আলো সম্পাদক
# 4387                       তথ্যপ্রযুক্তি খাতের আয় সব ছাড়িয়ে যাবে: জয়
# 4388                                                 কমেছে খেলাপি ঋণ
# 4389                              পেট্রোল বোমায় দগ্ধ আরেকজনের মৃত্যু
# 4390                  সৌদি গমনেচ্ছুদের ভিড় চট্টগ্রামে, নিবন্ধন ঢাকায়
#
#                                                                                                                                                                              clean_article  \
# 4287                                                  গোল্ড কাপ জয়ের লক্ষ্য পূরণের দারুণ সম্ভাবনা তৈরি না পারার ব্যর্থতায় হতাশ লোডভিক ডি ক্রুইফ বাংলাদেশ কোচ জানান দলের হার ভীষণ বেদনাদায়ক
# 4288  স্বাগতিক বাংলাদেশকে হারিয়ে বঙ্গবন্ধু গোল্ড কাপ জয়ের শিষ্যদের হার না মানসিকতার প্রশংসা মালয়েশিয়া কোচ রাজীব ইসমাইল গোল্ড কাপ জয়ের এএফসি অনূর্ধ্ব চ্যাম্পিয়নশিপের প্রস্তুতিও ভালো জানান
# 4290                                                                              জনগণের কষ্টার্জিত অর্থের অপচয় কঠোরভাবে নিয়ন্ত্রণ সংশ্লিষ্টদের আহ্বান জানিয়েছেন রাষ্ট্রপতি মো আবদুল হামিদ
# 4291      ডোয়াইন ব্র্যাভো কাইরন পোলার্ডের না থাকাটা দলের বড় ক্ষতি হিসেবে মানছেন ওয়েস্ট ইন্ডিজের অধিনায়ক জেসন হোল্ডার দুজনকে বিশ্বকাপ দলে না নির্বাচকদের সিদ্ধান্তে অসন্তোষও লুকোনোর করেননি
# 4292                                                                                           রাষ্ট্রপতি মো আবদুল হামিদের সৌজন্য সাক্ষাৎ মালদ্বীপের ন্যাশনাল ডিফেন্স ফোর্সের প্রতিনিধি দল
# ...                                                                                                                                                                                    ...
# 4386                                                                                   ধর্মীয় অনুভূতিতে আঘাত মামলায় ঠাকুরগাঁওয়ের আদালতে হাজির জামিন নিয়েছেন দৈনিক আলোর সম্পাদক মতিউর রহমান
# 4387                     তথ্য যোগাযোগ প্রযুক্তি খাতে বাংলাদেশের বৈদেশিক আয়ের পরিমাণ শিগগির তৈরি পোশাক খাতকে ছাড়িয়ে আশা প্রধানমন্ত্রীর তথ্য যোগাযোগ প্রযুক্তি বিষয়ক উপদেষ্টা সজীব ওয়াজেদ জয়
# 4388                                                                                                                                   ব্যাংকিং খাতে খেলাপি ঋণ কমেছে দাবি কেন্দ্রীয় ব্যাংক
# 4389                                                                                                              মৃত্যুর লড়াই হার মানলেন রাজশাহীতে পেট্রোল বোমায় দগ্ধ ট্রাক চালকের সহকারী
# 4390                                                                          সৌদি আরবে কর্মী পাঠাতে নিবন্ধন ধারণার ভিত্তিতে চট্টগ্রামের জেলা কর্মসংস্থান জনশক্তি কার্যালয়ে ভিড় জমায় কয়েকশ
#
#                                                                clean_summary
# 4287                                    _START_ ক্রুইফের বেদনাদায়ক হার _END_
# 4288                   _START_ শিষ্যদের প্রশংসায় পঞ্চমুখ মালয়েশিয়া কোচ _END_
# 4290                   _START_ অপচয় কঠোরভাবে নিয়ন্ত্রণ হবে: রাষ্ট্রপতি _END_
# 4291                    _START_ ব্র্যাভো পোলার্ড না থাকাটা বিরাট ক্ষতি _END_
# 4292  _START_ রাষ্ট্রপতির মালদ্বীপের প্রতিরক্ষা প্রতিনিধি দলের সাক্ষাৎ _END_
# ...                                                                      ...
# 4386                                   _START_ জামিন পেলেন আলো সম্পাদক _END_
# 4387                    _START_ তথ্যপ্রযুক্তি খাতের আয় ছাড়িয়ে যাবে: জয় _END_
# 4388                                           _START_ কমেছে খেলাপি ঋণ _END_
# 4389                        _START_ পেট্রোল বোমায় দগ্ধ আরেকজনের মৃত্যু _END_
# 4390            _START_ সৌদি গমনেচ্ছুদের ভিড় চট্টগ্রামে, নিবন্ধন ঢাকায় _END_
#
# [103 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in new_df['clean_article'] :
      text_word_count.append(len(i.split()))

for i in new_df['clean_summary'] :
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'article':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
print("max word in summary : ", max(summary_word_count))
print("max word in article : ", max(text_word_count))

print("min word in summary : ", min(summary_word_count))
print("min word in article : ", min(text_word_count))
# Out:
# max word in summary :  12
# max word in article :  49
# min word in summary :  3
# min word in article :  1

# %%
max_len_text=50
max_len_summary=15
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(new_df['clean_article'], new_df['clean_summary'],test_size=0.1,random_state=0)

# %%
word2vec = {}
with open('/content/gdrive/MyDrive/Bangla_News_Article_Dataset/bn_glove.39M.300d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vec = np.asarray(values[1:], dtype='float32')
        word2vec[word] = vec

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))
x_word2idx = x_tokenizer.word_index

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) + 1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))
y_word2idx = y_tokenizer.word_index

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) + 1

# %%
embedding_dim = len(next(iter(word2vec.values())))

# %%
# create embedding matrix for x
x_embedding_matrix = np.zeros((x_voc_size, embedding_dim))
for word, i in x_word2idx.items():
    embedding_vector = word2vec.get(word)
    if embedding_vector is not None:
        x_embedding_matrix[i] = embedding_vector

# %%
# create embedding matrix for y
y_embedding_matrix = np.zeros((y_voc_size, embedding_dim))
for word, i in y_word2idx.items():
    embedding_vector = word2vec.get(word)
    if embedding_vector is not None:
        y_embedding_matrix[i] = embedding_vector

# %%
import tensorflow as tf
import os
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
class SelfAttention(Layer):
    def __init__(self, units, **kwargs):
        self.units = units
        super().__init__(**kwargs)

    def build(self, input_shape):
        hidden_size = input_shape[2]
        self.WQ = self.add_weight(name='WQ',
                                  shape=tf.TensorShape((hidden_size, self.units)),
                                  initializer='glorot_uniform',
                                  trainable=True)
        self.WK = self.add_weight(name='WK',
                                  shape=tf.TensorShape((hidden_size, self.units)),
                                  initializer='glorot_uniform',
                                  trainable=True)
        self.WV = self.add_weight(name='WV',
                                  shape=tf.TensorShape((hidden_size, self.units)),
                                  initializer='glorot_uniform',
                                  trainable=True)

    def call(self, inputs):
        Q = tf.keras.backend.dot(inputs, self.WQ)
        K = tf.keras.backend.dot(inputs, self.WK)
        V = tf.keras.backend.dot(inputs, self.WV)
        attn_scores = tf.keras.backend.batch_dot(Q, K, axes=[2, 2]) / (K.shape[-1] ** 0.5)
        attn_weights = tf.keras.backend.softmax(attn_scores)
        attn_out = tf.keras.backend.batch_dot(attn_weights, V, axes=[2, 1])
        return attn_out, attn_scores

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 512 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, embedding_dim, weights=[x_embedding_matrix], trainable=False)(encoder_inputs)

#LSTM 1 
encoder_lstm1 = Bidirectional(LSTM(latent_dim,return_sequences=True,return_state=True)) 
encoder_output1, forward_h1, forward_c1, backward_h1, backward_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = Bidirectional(LSTM(latent_dim,return_sequences=True,return_state=True)) 
encoder_output2, forward_h2, forward_c2, backward_h2, backward_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3 = Bidirectional(LSTM(latent_dim, return_state=True, return_sequences=True)) 
encoder_outputs, forward_h3, forward_c3, backward_h3, backward_c3 = encoder_lstm3(encoder_output2) 

# Concatenate the forward and backward hidden states of the last LSTM layer
state_h = Concatenate()([forward_h3, backward_h3])
state_c = Concatenate()([forward_c3, backward_c3])

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, embedding_dim, weights=[y_embedding_matrix], trainable=False) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim*2, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

# Apply self-attention
self_attn_layer = SelfAttention(units=latent_dim*2, name='self_attention_layer')

self_attn_out, self_attn_scores = self_attn_layer(decoder_outputs)

# Apply attention
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_scores = attn_layer([encoder_outputs, self_attn_out])

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50)]         0           []
#
#  embedding (Embedding)          (None, 50, 300)      10284600    ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  [(None, 50, 1024),   3330048     ['embedding[0][0]']
#                                  (None, 512),
#                                  (None, 512),
#                                  (None, 512),
#                                  (None, 512)]
#
#  bidirectional_1 (Bidirectional  [(None, 50, 1024),  6295552     ['bidirectional[0][0]']
#  )                               (None, 512),
#                                  (None, 512),
#                                  (None, 512),
#                                  (None, 512)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  bidirectional_2 (Bidirectional  [(None, 50, 1024),  6295552     ['bidirectional_1[0][0]']
#  )                               (None, 512),
#                                  (None, 512),
#                                  (None, 512),
#                                  (None, 512)]
#
#  embedding_1 (Embedding)        (None, None, 300)    5742900     ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 1024)         0           ['bidirectional_2[0][1]',
#                                                                   'bidirectional_2[0][3]']
#
#  concatenate_1 (Concatenate)    (None, 1024)         0           ['bidirectional_2[0][2]',
#                                                                   'bidirectional_2[0][4]']
#
#  lstm_3 (LSTM)                  [(None, None, 1024)  5427200     ['embedding_1[0][0]',
#                                 , (None, 1024),                   'concatenate[0][0]',
#                                  (None, 1024)]                    'concatenate_1[0][0]']
#
#  self_attention_layer (SelfAtte  ((None, None, 1024)  3145728    ['lstm_3[0][0]']
#  ntion)                         , (None, None, None
#                                 ))
#
#  attention_layer (AttentionLaye  ((None, None, 1024)  2098176    ['bidirectional_2[0][0]',
#  r)                             , (None, None, 50))               'self_attention_layer[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 2048)   0           ['lstm_3[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  time_distributed (TimeDistribu  (None, None, 19143)  39224007   ['concat_layer[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 81,843,763
# Trainable params: 65,816,263
# Non-trainable params: 16,027,500
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
x_tr
y_tr[:,:-1]
y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:]
# Out:
# array([[[ 1219],
#         [ 1822],
#         [  143],
#         ...,
#         [    0],
#         [    0],
#         [    0]],
#
#        [[  398],
#         [ 1220],
#         [  281],
#         ...,
#         [    0],
#         [    0],
#         [    0]],
#
#        [[ 5564],
#         [ 2807],
#         [ 8343],
#         ...,
#         [    0],
#         [    0],
#         [    0]],
#
#        ...,
#
#        [[  168],
#         [ 2514],
#         [  771],
#         ...,
#         [    0],
#         [    0],
#         [    0]],
#
#        [[  635],
#         [19142],
#         [  579],
#         ...,
#         [    0],
#         [    0],
#         [    0]],
#
#        [[ 8339],
#         [  667],
#         [ 1235],
#         ...,
#         [    0],
#         [    0],
#         [    0]]], dtype=int32)

# %%
y_tr[:,:-1].shape
y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:].shape
x_tr.shape
# Out:
# (17184, 50)

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
history=model.fit([x_tr, y_tr[:,:-1]], 
                  y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,
                  epochs=20,
                  callbacks=[early_stopping],
                  batch_size=64, 
                  validation_data=([x_val,y_val[:,:-1]], 
                  y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:])
                 )
# Out:
# Epoch 1/20
# 269/269 [==============================] - 95s 331ms/step - loss: 2.4971 - accuracy: 0.6674 - val_loss: 2.2605 - val_accuracy: 0.7001
# Epoch 2/20
# 269/269 [==============================] - 89s 330ms/step - loss: 2.2778 - accuracy: 0.6727 - val_loss: 2.1981 - val_accuracy: 0.7030
# Epoch 3/20
# 269/269 [==============================] - 89s 330ms/step - loss: 2.0993 - accuracy: 0.6786 - val_loss: 2.1972 - val_accuracy: 0.7033
# Epoch 4/20
# 269/269 [==============================] - 88s 328ms/step - loss: 1.9301 - accuracy: 0.6858 - val_loss: 2.1649 - val_accuracy: 0.7080
# Epoch 5/20
# 269/269 [==============================] - 88s 328ms/step - loss: 1.7654 - accuracy: 0.6936 - val_loss: 2.1578 - val_accuracy: 0.7110
# Epoch 6/20
# 269/269 [==============================] - 88s 327ms/step - loss: 1.6047 - accuracy: 0.7041 - val_loss: 2.1644 - val_accuracy: 0.7079
# Epoch 7/20
# 269/269 [==============================] - 88s 328ms/step - loss: 1.4397 - accuracy: 0.7187 - val_loss: 2.1548 - val_accuracy: 0.7130
# Epoch 8/20
# 269/269 [==============================] - 88s 328ms/step - loss: 1.2781 - accuracy: 0.7394 - val_loss: 2.1578 - val_accuracy: 0.7112
# Epoch 9/20
# 269/269 [==============================] - 88s 329ms/step - loss: 1.1159 - accuracy: 0.7669 - val_loss: 2.2471 - val_accuracy: 0.6944
# Epoch 10/20
# 269/269 [==============================] - 88s 328ms/step - loss: 0.9618 - accuracy: 0.7983 - val_loss: 2.2149 - val_accuracy: 0.7022

# %%
#Visualizing Loss 
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
#Building Dictionary for Source Vocabulary
reverse_target_word_index = y_tokenizer.index_word 
reverse_source_word_index = x_tokenizer.index_word 
target_word_index = y_tokenizer.word_index
target_word_index['start'] = 1
target_word_index['end'] = 2

# %%
def my_filtering_function(pair):
    key, value = pair
    if (value == "start" or value == "end") :
        return True  # keep pair in the filtered dictionary
    else:
        return False  # filter pair out of the dictionary

# %%
# # Add 'start' and 'end' tokens to target_word_index dictionary
# target_word_index['start'] = len(target_word_index)+1
# target_word_index['end'] = len(target_word_index)+1

# # Update reverse_target_word_index dictionary
# reverse_target_word_index = dict((i, word) for word, i in target_word_index.items())

# %%
filtered_grades = dict(filter(my_filtering_function, target_word_index.items()))
 
print(filtered_grades)
# Out:
# {}

# %%
target_word_index
# Out:
# {'start': 1,
#  'end': 2,
#  'নিহত': 3,
#  'গ্রেপ্তার': 4,
#  'না': 5,
#  'চট্টগ্রামে': 6,
#  'মৃত্যু': 7,
#  'আটক': 8,
#  '২': 9,
#  'উদ্ধার': 10,
#  '৩': 11,
#  'লাশ': 12,
#  'হত্যা': 13,
#  'আহত': 14,
#  'বোমা': 15,
#  'আগুন': 16,
#  'বিরুদ্ধে': 17,
#  'জয়': 18,
#  '১': 19,
#  '৫': 20,
#  'অভিযোগ': 21,
#  '৪': 22,
#  'পেট্রোল': 23,
#  'বাংলাদেশ': 24,
#  'খালেদার': 25,
#  'দাবি': 26,
#  'নেতা': 27,
#  'হামলা': 28,
#  'পুলিশ': 29,
#  'হামলায়': 30,
#  'সংঘর্ষে': 31,
#  'মামলায়': 32,
#  '১০': 33,
#  'হত্যার': 34,
#  'বিএনপি': 35,
#  'যুবক': 36,
#  'ঢাকায়': 37,
#  'বাংলাদেশের': 38,
#  'গাজীপুরে': 39,
#  'দুর্ঘটনায়': 40,
#  'পুলিশের': 41,
#  'বাসে': 42,
#  'নিউ': 43,
#  'বিএনপির': 44,
#  'দগ্ধ': 45,
#  'খুন': 46,
#  'খালেদা': 47,
#  '৭': 48,
#  'প্রধানমন্ত্রী': 49,
#  'টাকা': 50,
#  'সোনা': 51,
#  'জঙ্গি': 52,
#  'প্রধানমন্ত্রীর': 53,
#  'বড়': 54,
#  '৬': 55,
#  'নয়': 56,
#  'শিশু': 57,
#  'ফেনীতে': 58,
#  'লাখ': 59,
#  'ধাক্কায়': 60,
#  'সময়': 61,
#  'যুবকের': 62,
#  'কুপিয়ে': 63,
#  'চট্টগ্রাম': 64,
#  'আ': 65,
#  'বেড়েছে': 66,
#  'হরতাল': 67,
#  'হারিয়ে': 68,
#  'ঢাকা': 69,
#  'নারী': 70,
#  'সংঘর্ষ': 71,
#  'আসছে': 72,
#  'আহ্বান': 73,
#  'আসামি': 74,
#  'গুলিতে': 75,
#  'হামলার': 76,
#  'ম্যাচ': 77,
#  'শিশুর': 78,
#  'ভারতের': 79,
#  '৮': 80,
#  'রেকর্ড': 81,
#  'রাজশাহীতে': 82,
#  'বাংলাদেশি': 83,
#  'সিরাজগঞ্জে': 84,
#  'হবে': 85,
#  'ঈদ': 86,
#  'বোমায়': 87,
#  'অভিযোগে': 88,
#  '১৫': 89,
#  'ট্রাকে': 90,
#  'সৌদি': 91,
#  'বিচার': 92,
#  'হাতবোমা': 93,
#  'দল': 94,
#  'নিখোঁজ': 95,
#  'জাতীয়': 96,
#  'হার': 97,
#  'পথে': 98,
#  'ব্যাংক': 99,
#  'সিলেটে': 100,
#  'আইএস': 101,
#  'লীগের': 102,
#  'কমিটি': 103,
#  'গাড়ি': 104,
#  'হুমকি': 105,
#  'ধর্ষণ': 106,
#  'বিপক্ষে': 107,
#  'ওপর': 108,
#  'সড়ক': 109,
#  'শ্রমিক': 110,
#  'শোক': 111,
#  'রাজধানীতে': 112,
#  'আগুনে': 113,
#  'রিমান্ডে': 114,
#  'বিশ্বকাপ': 115,
#  'ভারতে': 116,
#  'ম্যাচে': 117,
#  'চট্টগ্রামের': 118,
#  'খালেদাকে': 119,
#  'বগুড়ায়': 120,
#  'পরীক্ষা': 121,
#  'যুক্তরাষ্ট্রের': 122,
#  'বিস্ফোরণে': 123,
#  'দক্ষিণ': 124,
#  'বন্দুকযুদ্ধে': 125,
#  'লীগ': 126,
#  'চাঁদপুরে': 127,
#  'নেতার': 128,
#  'কোচ': 129,
#  'যুক্তরাষ্ট্রে': 130,
#  'বিমান': 131,
#  'সরকার': 132,
#  '২০': 133,
#  'বাস': 134,
#  'ভারত': 135,
#  'মাঠে': 136,
#  'হত্যায়': 137,
#  'কাদের': 138,
#  'পুঁজিবাজারে': 139,
#  'প্রধান': 140,
#  'চুক্তি': 141,
#  'কারাগারে': 142,
#  'দলে': 143,
#  'মার্কিন': 144,
#  'প্রতিবাদ': 145,
#  'যাবজ্জীবন': 146,
#  'বরিশালে': 147,
#  'ব্যাংকের': 148,
#  'পড়ে': 149,
#  'তদন্ত': 150,
#  'গোপালগঞ্জে': 151,
#  'বিস্ফোরণ': 152,
#  'হাতে': 153,
#  'নিরাপত্তা': 154,
#  'নাশকতার': 155,
#  'নেই': 156,
#  'মেয়র': 157,
#  '১২': 158,
#  'দলের': 159,
#  'মামলার': 160,
#  'গোলে': 161,
#  'নোয়াখালীতে': 162,
#  'শেখ': 163,
#  'পাকিস্তান': 164,
#  'বাসের': 165,
#  'ভারতীয়': 166,
#  'শীর্ষে': 167,
#  'বাধা': 168,
#  'রায়': 169,
#  'ধর্ষণের': 170,
#  'রাষ্ট্রপতির': 171,
#  'কুমিল্লায়': 172,
#  'দিনাজপুরে': 173,
#  'রোনালদো': 174,
#  'ফরিদপুরে': 175,
#  'অস্ট্রেলিয়ার': 176,
#  'শিক্ষক': 177,
#  'বাজারে': 178,
#  'নারায়ণগঞ্জে': 179,
#  'ইয়র্কে': 180,
#  'যশোরে': 181,
#  '৩০': 182,
#  'অগ্নিকাণ্ড': 183,
#  'পেলেন': 184,
#  '১৪': 185,
#  'দিনে': 186,
#  'জয়ের': 187,
#  'লক্ষ্য': 188,
#  'ডুবে': 189,
#  'অবরোধ': 190,
#  'গুলিবিদ্ধ': 191,
#  'ফাইনালে': 192,
#  'গাইবান্ধায়': 193,
#  'দাবিতে': 194,
#  'পিটিয়ে': 195,
#  'দেবে': 196,
#  'জামিন': 197,
#  'চালক': 198,
#  'জয়ে': 199,
#  'গাড়িতে': 200,
#  'স্বপ্ন': 201,
#  'ট্রাকচাপায়': 202,
#  'মেসির': 203,
#  'তথ্য': 204,
#  'ইফতার': 205,
#  'পাকিস্তানের': 206,
#  'আশা': 207,
#  'কক্সবাজারে': 208,
#  'অস্ত্র': 209,
#  'পুড়ল': 210,
#  'বাড়িতে': 211,
#  'এগিয়ে': 212,
#  'জরিমানা': 213,
#  'ঈদের': 214,
#  'টাকার': 215,
#  '৯': 216,
#  'ভাংচুর': 217,
#  'দিল': 218,
#  'সীমান্তে': 219,
#  'কমেছে': 220,
#  'মেসি': 221,
#  'কথা': 222,
#  'হাসিনা': 223,
#  'ছাত্রলীগ': 224,
#  'ইতিহাস': 225,
#  'নির্দেশ': 226,
#  'পেল': 227,
#  'আদালতে': 228,
#  'ইয়াবাসহ': 229,
#  'বিশ্বকাপে': 230,
#  'কার্যালয়ে': 231,
#  'আওয়ামী': 232,
#  'নির্বাচন': 233,
#  'ভালো': 234,
#  'অস্ত্রসহ': 235,
#  'সুযোগ': 236,
#  'মৃত্যুদণ্ড': 237,
#  'সাভারে': 238,
#  'সিনেমা': 239,
#  'ঝিনাইদহে': 240,
#  'ট্রাক': 241,
#  'হাই': 242,
#  'নিষিদ্ধ': 243,
#  'নারীর': 244,
#  'লক্ষ্মীপুরে': 245,
#  'পাহাড়': 246,
#  'জয়পুরহাটে': 247,
#  'মুখে': 248,
#  'দাম': 249,
#  'দেশে': 250,
#  'অ্যাপল': 251,
#  'মা': 252,
#  'সাংবাদিক': 253,
#  'সংসদে': 254,
#  'শ্রমিকের': 255,
#  'যুক্তরাষ্ট্র': 256,
#  'পুরস্কার': 257,
#  'প্রকাশ': 258,
#  'হাসপাতালে': 259,
#  'চেয়ারম্যান': 260,
#  'ডাকাত': 261,
#  'মুক্তি': 262,
#  'বিক্ষোভ': 263,
#  'বাড়ি': 264,
#  'রিয়াল': 265,
#  'ধসে': 266,
#  'স্থগিত': 267,
#  'উড়িয়ে': 268,
#  'ফখরুল': 269,
#  'কর্মকর্তা': 270,
#  'চাই': 271,
#  'লড়াই': 272,
#  'চীনের': 273,
#  'চুরি': 274,
#  'ছিনতাই': 275,
#  'গুগল': 276,
#  'নেতাকে': 277,
#  'রিয়ালের': 278,
#  'কেজি': 279,
#  'চাঁপাইনবাবগঞ্জে': 280,
#  'ট্রাম্প': 281,
#  'অপেক্ষায়': 282,
#  'একজন': 283,
#  'ট্রাকের': 284,
#  'বছরের': 285,
#  'মাগুরায়': 286,
#  'শতকে': 287,
#  'একজনের': 288,
#  'নিষেধাজ্ঞা': 289,
#  'চিঠি': 290,
#  'অস্ট্রেলিয়া': 291,
#  'জেএমবি': 292,
#  'রাষ্ট্রপতি': 293,
#  'হবিগঞ্জে': 294,
#  'বাংলা': 295,
#  'তৃতীয়': 296,
#  'শিরোপা': 297,
#  'দোকান': 298,
#  'সহজ': 299,
#  'ফল': 300,
#  'সাক্ষাৎ': 301,
#  'সিটি': 302,
#  'মুন্সীগঞ্জে': 303,
#  'সবচেয়ে': 304,
#  'আরোহী': 305,
#  'অবৈধ': 306,
#  'কারাদণ্ড': 307,
#  'স্কুল': 308,
#  'ছাত্র': 309,
#  '১৬': 310,
#  'পাকিস্তানে': 311,
#  '১১': 312,
#  'বরখাস্ত': 313,
#  'বিল': 314,
#  'ঢাকার': 315,
#  'জোড়া': 316,
#  'নদীতে': 317,
#  'নাশকতা': 318,
#  'দিনের': 319,
#  'শতাংশ': 320,
#  'অভিযান': 321,
#  'মন্ত্রী': 322,
#  'অর্থ': 323,
#  'প্রত্যাহার': 324,
#  'সহায়তা': 325,
#  'নামে': 326,
#  'পোশাক': 327,
#  'ফেইসবুক': 328,
#  'ডলার': 329,
#  'চ্যাম্পিয়ন': 330,
#  'দায়ে': 331,
#  'বঙ্গবন্ধু': 332,
#  'বজ্রপাতে': 333,
#  'পরোয়ানা': 334,
#  'বিদায়': 335,
#  'দিবসে': 336,
#  'মোটরসাইকেল': 337,
#  'বাংলাদেশে': 338,
#  'বেনাপোলে': 339,
#  'জামায়াত': 340,
#  'চুয়াডাঙ্গায়': 341,
#  'বিশ্ববিদ্যালয়': 342,
#  'সভা': 343,
#  'বাড়ছে': 344,
#  'গেলেন': 345,
#  'সরকারি': 346,
#  'ঘটনায়': 347,
#  'স্বাধীনতা': 348,
#  'রোনালদোর': 349,
#  'প্রবাসী': 350,
#  'মিলল': 351,
#  'প্রস্তুতি': 352,
#  '২৫': 353,
#  'ট্রেনে': 354,
#  'প্রতিবেদন': 355,
#  'বাগেরহাটে': 356,
#  'দ্বিতীয়': 357,
#  'ময়মনসিংহে': 358,
#  '১৩': 359,
#  'স্ত্রী': 360,
#  'নিলেন': 361,
#  'ছবি': 362,
#  'ডি': 363,
#  'ড্র': 364,
#  'সাড়ে': 365,
#  'বাংলাদেশকে': 366,
#  'আবেদন': 367,
#  'যুবককে': 368,
#  'শিবির': 369,
#  'ঠেকাতে': 370,
#  'উল্টে': 371,
#  'মাশরাফি': 372,
#  'আরো': 373,
#  '৫০': 374,
#  'সিদ্ধান্ত': 375,
#  'সেনা': 376,
#  'ব্রাজিলের': 377,
#  'অভিজিৎ': 378,
#  'পেছাল': 379,
#  'পরিকল্পনা': 380,
#  'বাজেট': 381,
#  'চলছে': 382,
#  'চাল': 383,
#  'কর্মসূচি': 384,
#  'পুড়েছে': 385,
#  'চীন': 386,
#  'রংপুরে': 387,
#  'জেলায়': 388,
#  'ট্রেন': 389,
#  'বছরে': 390,
#  'নির্বাচনে': 391,
#  'বিধ্বস্ত': 392,
#  'সেমিতে': 393,
#  'নেত্রকোণায়': 394,
#  'মেলা': 395,
#  'শ্রীলঙ্কার': 396,
#  'সিরিয়ায়': 397,
#  'প্রেসিডেন্ট': 398,
#  'লেনদেন': 399,
#  'অগাস্ট': 400,
#  'মৃত্যুতে': 401,
#  'জখম': 402,
#  'ঘণ্টা': 403,
#  'তৈরি': 404,
#  'ছাত্রদল': 405,
#  'শতাধিক': 406,
#  'কেটে': 407,
#  'কর্মী': 408,
#  'চীনে': 409,
#  'যুবলীগ': 410,
#  'গৃহবধূকে': 411,
#  'পরীক্ষার': 412,
#  'অনুমোদন': 413,
#  'দ্রুত': 414,
#  'করুন': 415,
#  'ভোট': 416,
#  'হলেন': 417,
#  'স্ত্রীর': 418,
#  'বোমাসহ': 419,
#  'ইয়াবা': 420,
#  'নীলফামারীতে': 421,
#  'ইউপি': 422,
#  'বাতিল': 423,
#  'ব্রিটিশ': 424,
#  '৪০': 425,
#  'উৎসব': 426,
#  'ভূমি': 427,
#  'ট্রেনের': 428,
#  'কোচের': 429,
#  'রিজভী': 430,
#  'গান': 431,
#  'মুহিত': 432,
#  'অগ্নিসংযোগ': 433,
#  'বাসচাপায়': 434,
#  'আবারও': 435,
#  'ইংল্যান্ড': 436,
#  'ইংল্যান্ডের': 437,
#  'বঙ্গবন্ধুর': 438,
#  'অধিনায়ক': 439,
#  'যাচ্ছেন': 440,
#  'অটোরিকশা': 441,
#  'শঙ্কা': 442,
#  'বার্সার': 443,
#  'বার্সা': 444,
#  'ব্রাজিল': 445,
#  'আইএসের': 446,
#  'টাঙ্গাইলে': 447,
#  'বিমানের': 448,
#  'বিএনপিজামায়াতের': 449,
#  'ঈদে': 450,
#  'তদন্তে': 451,
#  'আরেক': 452,
#  'নওগাঁয়': 453,
#  'স্মরণ': 454,
#  'ভয়': 455,
#  'আটে': 456,
#  'বিদ্যুৎ': 457,
#  '২২': 458,
#  'বুধবার': 459,
#  'সফরে': 460,
#  'ট্রাম্পের': 461,
#  'অবরোধের': 462,
#  'এসএসসি': 463,
#  'শুল্ক': 464,
#  'সালাহ': 465,
#  'শুনানি': 466,
#  'লড়াইয়ে': 467,
#  'আরেকটি': 468,
#  'খান': 469,
#  'আফ্রিকার': 470,
#  '১৭': 471,
#  'প্রতিমন্ত্রী': 472,
#  'জিল্যান্ড': 473,
#  'ভুল': 474,
#  'ছাত্রলীগের': 475,
#  'নাশকতায়': 476,
#  'লন্ডনে': 477,
#  'প্রাণ': 478,
#  'প্রস্তাব': 479,
#  'কাটা': 480,
#  'মোবাইল': 481,
#  'মানববন্ধন': 482,
#  'ম্যাচের': 483,
#  'প্রস্তুত': 484,
#  'শিক্ষার্থীদের': 485,
#  'মে': 486,
#  'বাবা': 487,
#  'আসছেন': 488,
#  'সর্বোচ্চ': 489,
#  'মাদক': 490,
#  'প্রার্থী': 491,
#  'নেতাকর্মী': 492,
#  'শিশুকে': 493,
#  'খুলনায়': 494,
#  'প্রশ্ন': 495,
#  'মুক্ত': 496,
#  'দেশের': 497,
#  'চাপায়': 498,
#  'শ্রমিকদের': 499,
#  '১৮': 500,
#  'ফাঁস': 501,
#  'অনুমতি': 502,
#  'ঠাকুরগাঁওয়ে': 503,
#  'সালমান': 504,
#  'বিশ্ববিদ্যালয়ে': 505,
#  'অ্যাপ': 506,
#  'মুখোমুখি': 507,
#  'কারখানায়': 508,
#  'ইয়েমেনে': 509,
#  'চাপ': 510,
#  'শিবিরের': 511,
#  'ছয়': 512,
#  'ক্ষতি': 513,
#  'অবরোধে': 514,
#  'ছাড়িয়ে': 515,
#  'টেকনাফে': 516,
#  'দায়': 517,
#  'ব্যবসায়ী': 518,
#  'মহাসড়কে': 519,
#  'বিদেশি': 520,
#  'স্ত্রীকে': 521,
#  'বন্ধের': 522,
#  '২৪': 523,
#  'শিকার': 524,
#  'সাকিব': 525,
#  'ধাক্কা': 526,
#  'নেইমার': 527,
#  'সতর্ক': 528,
#  'বিনিয়োগ': 529,
#  'মেয়েদের': 530,
#  'গৃহবধূর': 531,
#  'ব্রাহ্মণবাড়িয়ায়': 532,
#  'গ্যাস': 533,
#  'অপহৃত': 534,
#  'শিবিরকর্মী': 535,
#  'বিয়ে': 536,
#  'সরকারের': 537,
#  'কোরিয়ার': 538,
#  'ফেরত': 539,
#  'নেইমারের': 540,
#  'রোববার': 541,
#  'জেলা': 542,
#  'বাহিনীর': 543,
#  'শনিবার': 544,
#  'পাবনায়': 545,
#  'অপহরণ': 546,
#  'জাতিসংঘ': 547,
#  'সভাপতি': 548,
#  'ব্যাংকে': 549,
#  'শতক': 550,
#  'কোকোর': 551,
#  'নাটোরে': 552,
#  'খাদে': 553,
#  'দুর্নীতি': 554,
#  'ঢাবি': 555,
#  'আশুলিয়ায়': 556,
#  'অসুস্থ': 557,
#  'নাসিম': 558,
#  'চালকের': 559,
#  'ভুয়া': 560,
#  'মৃত্যুর': 561,
#  'ক্রিকেট': 562,
#  'পরামর্শ': 563,
#  'শাস্তি': 564,
#  'প্রশংসায়': 565,
#  'প্রবাসীদের': 566,
#  'মাদারীপুরে': 567,
#  'বিক্রি': 568,
#  'আয়োজন': 569,
#  'ব্যবস্থা': 570,
#  'কর্মকর্তার': 571,
#  'বই': 572,
#  'শ্রীলঙ্কা': 573,
#  'টানা': 574,
#  'আলোচনা': 575,
#  'ধস': 576,
#  'মিছিল': 577,
#  'শেরপুরে': 578,
#  'রাখতে': 579,
#  'ছাড়': 580,
#  'উদ্বেগ': 581,
#  'বিভাগ': 582,
#  'ফোন': 583,
#  'বৃহস্পতিবার': 584,
#  'ছুরিকাঘাতে': 585,
#  'আদালত': 586,
#  'দিবস': 587,
#  'বোকো': 588,
#  'গলা': 589,
#  'হচ্ছে': 590,
#  'ভেঙে': 591,
#  'ম্যান': 592,
#  '২১': 593,
#  'হরতালের': 594,
#  'মাস': 595,
#  'জিয়ার': 596,
#  'নেমে': 597,
#  'খাবার': 598,
#  'সন্দেহভাজন': 599,
#  'চলচ্চিত্র': 600,
#  'ব্যক্তির': 601,
#  'শিক্ষার্থী': 602,
#  'কমিটির': 603,
#  'সন্ত্রাসী': 604,
#  'ভাইয়ের': 605,
#  'সন্দেহে': 606,
#  'সংবাদ': 607,
#  'আনল': 608,
#  'বিভাগের': 609,
#  'জবাব': 610,
#  'বিএসএফের': 611,
#  'পুরান': 612,
#  'নিখোঁজ': 613,
#  'নিরাপত্তায়': 614,
#  'ভবন': 615,
#  'ডাক': 616,
#  'সাইবার': 617,
#  'বিবৃতি': 618,
#  'সাজা': 619,
#  'হাসিনার': 620,
#  'কুষ্টিয়ায়': 621,
#  'পদত্যাগ': 622,
#  'বিক্রেতা': 623,
#  'ভারতকে': 624,
#  'নরসিংদীতে': 625,
#  'পরিবার': 626,
#  'অভিযানে': 627,
#  'নাগঞ্জে': 628,
#  'বিতরণ': 629,
#  'মাশরাফির': 630,
#  'ওবামা': 631,
#  'গ্রেপ্তারে': 632,
#  'বিশ্বকাপের': 633,
#  'ভিডিও': 634,
#  'প্রকল্প': 635,
#  'চলবে': 636,
#  'সংলাপ': 637,
#  'আফ্রিকা': 638,
#  'রাজশাহী': 639,
#  'অফিসে': 640,
#  'দখলে': 641,
#  'গোল': 642,
#  'আরব': 643,
#  'হানিফ': 644,
#  'আলোচনায়': 645,
#  'সমাবেশ': 646,
#  'সম্মেলন': 647,
#  'পরিসংখ্যানে': 648,
#  'ঝুলন্ত': 649,
#  'বাড়াতে': 650,
#  'সচিব': 651,
#  'বন্দরে': 652,
#  'ভর্তি': 653,
#  'ড্রোন': 654,
#  'সাতক্ষীরায়': 655,
#  'সীতাকুণ্ডে': 656,
#  'সদস্যের': 657,
#  'শ্রদ্ধা': 658,
#  'প্রতিবাদে': 659,
#  'দিচ্ছে': 660,
#  'কেন্দ্রীয়': 661,
#  'ইউক্রেইনে': 662,
#  'কাপের': 663,
#  'পরিবারের': 664,
#  'মানুষের': 665,
#  'ফ্রান্সে': 666,
#  'নৈপুণ্যে': 667,
#  '১৯': 668,
#  'ভবনে': 669,
#  'যুবদল': 670,
#  'গ্যালাক্সি': 671,
#  'জমি': 672,
#  'খবর': 673,
#  'মৌলভীবাজারে': 674,
#  'আস্থা': 675,
#  'পাহাড়ে': 676,
#  'জব্দ': 677,
#  'খেলতে': 678,
#  'রূপগঞ্জে': 679,
#  'মনোনয়নপত্র': 680,
#  'মাসে': 681,
#  'আসামির': 682,
#  'ব্যর্থ': 683,
#  'গ্রেপ্তারের': 684,
#  'শেষে': 685,
#  'বিরোধী': 686,
#  'কোর্ট': 687,
#  'গাড়ির': 688,
#  'ফিরলেন': 689,
#  'ফেইসবুকে': 690,
#  'করল': 691,
#  'উপায়': 692,
#  'হারাল': 693,
#  'স্যামসাং': 694,
#  'শিক্ষা': 695,
#  'চূড়ান্ত': 696,
#  'যুদ্ধাপরাধ': 697,
#  'এমপি': 698,
#  'অভিনন্দন': 699,
#  'মন্ত্রীর': 700,
#  'নেওয়ার': 701,
#  'ব্যাটিং': 702,
#  'আরবে': 703,
#  'পাচ্ছে': 704,
#  'সাংবাদিকদের': 705,
#  'কার্যকর': 706,
#  'লভ্যাংশ': 707,
#  'দণ্ডিত': 708,
#  'কেন্দ্র': 709,
#  'শপথ': 710,
#  'শেয়ার': 711,
#  'স্বীকার': 712,
#  'খেলার': 713,
#  'চলাচল': 714,
#  'আল': 715,
#  'স্কুলে': 716,
#  'ফেরার': 717,
#  'সহিংসতা': 718,
#  'আয়': 719,
#  'জিল্যান্ডের': 720,
#  'পুকুরে': 721,
#  'জিয়া': 722,
#  'গুঁড়িয়ে': 723,
#  'রাখার': 724,
#  'বাহিনী': 725,
#  'সোনার': 726,
#  'ক্ষমতা': 727,
#  'বাসায়': 728,
#  'সমিতির': 729,
#  'ছেলের': 730,
#  'সুপারিশ': 731,
#  'কথিত': 732,
#  'ফাঁসি': 733,
#  'জামায়াতের': 734,
#  'কর': 735,
#  'রাশিয়ার': 736,
#  'প্রেসিডেন্টের': 737,
#  'কঠোর': 738,
#  'রোনালদোকে': 739,
#  'কোরিয়া': 740,
#  'র\u200c্যাবের': 741,
#  'ঋণ': 742,
#  'ইনু': 743,
#  'পাস': 744,
#  'হওয়ার': 745,
#  'চেষ্টা': 746,
#  'ঘিরে': 747,
#  'মেসিকে': 748,
#  'খুনের': 749,
#  'জামালপুরে': 750,
#  'জার্মানির': 751,
#  'ক্ষমা': 752,
#  'সমর্থন': 753,
#  'সিলেটের': 754,
#  'স্মার্টফোন': 755,
#  '৭০': 756,
#  'হোঁচট': 757,
#  'ভস্মীভূত': 758,
#  'একুশে': 759,
#  'সংসদ': 760,
#  'স্কুলছাত্র': 761,
#  'কাপে': 762,
#  'সমালোচনায়': 763,
#  'ঝুঁকিতে': 764,
#  'মারধর': 765,
#  'শিশুদের': 766,
#  'মৃত': 767,
#  'বিজিবি': 768,
#  'গৃহবধূ': 769,
#  '৩১': 770,
#  'দেশ': 771,
#  'জাতিসংঘের': 772,
#  'বাড়ির': 773,
#  'সেবা': 774,
#  'হচ্ছেন': 775,
#  'বাবার': 776,
#  'ঘরে': 777,
#  'ডাকাতি': 778,
#  'প্রশংসা': 779,
#  'সাকিবের': 780,
#  'ঘণ্টার': 781,
#  'ইসি': 782,
#  'রাষ্ট্রদূত': 783,
#  'পাচ্ছেন': 784,
#  'আন্তর্জাতিক': 785,
#  'বোলারদের': 786,
#  'দেখছেন': 787,
#  'এলাকায়': 788,
#  'পুড়ে': 789,
#  'বাড়ল': 790,
#  'সিরিজ': 791,
#  'অপেক্ষা': 792,
#  'নড়াইলে': 793,
#  'লন্ডন': 794,
#  'হাতবোমায়': 795,
#  'জিততে': 796,
#  'হেরে': 797,
#  'নিক্ষেপ': 798,
#  'উইন্ডিজ': 799,
#  'পুড়িয়ে': 800,
#  'দ': 801,
#  'বার্তা': 802,
#  'সাগরে': 803,
#  'মাংস': 804,
#  'লিগ': 805,
#  'চোট': 806,
#  'ফখরুলের': 807,
#  'টঙ্গীতে': 808,
#  'ছাত্রীকে': 809,
#  'বৈঠক': 810,
#  'সম্মেলনে': 811,
#  'মঙ্গলবার': 812,
#  'ডলারের': 813,
#  'স্বামী': 814,
#  'ব্যবসায়ীর': 815,
#  'আফগানিস্তানে': 816,
#  'মুক্তিযোদ্ধা': 817,
#  'নেতাদের': 818,
#  'মান্না': 819,
#  'ওবায়দুল': 820,
#  'হাত': 821,
#  'ব্যবসায়ীদের': 822,
#  'দশ': 823,
#  'আপিল': 824,
#  'চোখ': 825,
#  '৩৬': 826,
#  'কারখানার': 827,
#  'বিচারপতি': 828,
#  'কামাল': 829,
#  'স্কুলছাত্রের': 830,
#  'হতাশ': 831,
#  'আত্মহত্যা': 832,
#  'এয়ার': 833,
#  'ত্রাণ': 834,
#  'সুপ্রিম': 835,
#  'দারুণ': 836,
#  'সহকারী': 837,
#  'নোট': 838,
#  'মিছিলে': 839,
#  'গল্প': 840,
#  'অনুষ্ঠিত': 841,
#  'সমস্যা': 842,
#  'আনছে': 843,
#  'কামরুল': 844,
#  'পয়েন্ট': 845,
#  'কারণে': 846,
#  'কামারুজ্জামানের': 847,
#  'দাফন': 848,
#  'অ্যাপলের': 849,
#  'নেতাসহ': 850,
#  'মীর': 851,
#  'কাসেমের': 852,
#  'সংগ্রহ': 853,
#  'উবার': 854,
#  'থাকতে': 855,
#  'জাল': 856,
#  'গুলশানে': 857,
#  'বাংলাদেশির': 858,
#  'রাঙামাটিতে': 859,
#  'ভাই': 860,
#  'দেড়': 861,
#  'জেলে': 862,
#  'শঙ্কায়': 863,
#  'সম্পাদক': 864,
#  'ফেরা': 865,
#  'চৌধুরী': 866,
#  'পরমাণু': 867,
#  'ফ্রান্স': 868,
#  'ফ্রান্সের': 869,
#  'কার্যালয়ের': 870,
#  'আটকে': 871,
#  'ঝুঁকি': 872,
#  'রাতে': 873,
#  'মারা': 874,
#  'সতর্কতা': 875,
#  'জিম্মি': 876,
#  'খুশি': 877,
#  'তালিকা': 878,
#  'অর্থমন্ত্রী': 879,
#  'দরকার': 880,
#  'দূতের': 881,
#  'ক্লার্ক': 882,
#  'ছেড়ে': 883,
#  'বৃষ্টির': 884,
#  'মহিউদ্দিন': 885,
#  'বিশ্ববিদ্যালয়ের': 886,
#  'হক': 887,
#  'সিটির': 888,
#  'লালমনিরহাটে': 889,
#  'এড়াতে': 890,
#  'নেবে': 891,
#  'হাছান': 892,
#  'মায়ের': 893,
#  'সিলেট': 894,
#  'বরগুনায়': 895,
#  'যাত্রা': 896,
#  'প্রযুক্তি': 897,
#  'জীবন': 898,
#  'কলেজ': 899,
#  'ইন্টারনেট': 900,
#  'কোর্টের': 901,
#  'চীনা': 902,
#  'ক্ষেপণাস্ত্র': 903,
#  'রিভিউ': 904,
#  'বিএসএফ': 905,
#  'মেডিকেলে': 906,
#  'বোলিং': 907,
#  'হাসপাতাল': 908,
#  'কোর্টে': 909,
#  'উদযাপন': 910,
#  'স্বাভাবিক': 911,
#  'সিদ্দিকুর': 912,
#  'হওয়া': 913,
#  'রবি': 914,
#  'সুরঞ্জিত': 915,
#  '২৩': 916,
#  'নিহতের': 917,
#  'ধর্মঘট': 918,
#  'বোমাবাজি': 919,
#  'সাফল্য': 920,
#  'যুক্তরাজ্যে': 921,
#  'লন্ডনের': 922,
#  'বাজার': 923,
#  'ফেলে': 924,
#  'নিয়ন্ত্রণ': 925,
#  'টাকায়': 926,
#  'শহীদ': 927,
#  'আর্জেন্টিনা': 928,
#  'পরিবর্তন': 929,
#  'জঙ্গির': 930,
#  'পদ্মা': 931,
#  'বিরোধে': 932,
#  'শাহ': 933,
#  'মিসবাহ': 934,
#  'ক্ষোভ': 935,
#  'চেয়ারম্যানের': 936,
#  'তৈরির': 937,
#  'নৌকা': 938,
#  'রহমান': 939,
#  'তামিম': 940,
#  'আঘাতে': 941,
#  'পেতে': 942,
#  'সন্ত্রাস': 943,
#  'ইসলামী': 944,
#  'ছেলে': 945,
#  'স্কুলছাত্রী': 946,
#  'এফবিআই': 947,
#  'আফগান': 948,
#  'উইকেট': 949,
#  'স্বস্তি': 950,
#  'গাড়িবহরে': 951,
#  'কার্ড': 952,
#  'গোল্ড': 953,
#  'অভিযোগপত্র': 954,
#  'পরীক্ষায়': 955,
#  'কাউন্সিলর': 956,
#  'অবশেষে': 957,
#  'ফাঁসির': 958,
#  'থাকছেন': 959,
#  'বিপুল': 960,
#  'যত্ন': 961,
#  'দিবসের': 962,
#  'শাহ্জালাল': 963,
#  'সন্ধান': 964,
#  'স্বামীর': 965,
#  'অধ্যাপক': 966,
#  'চ্যালেঞ্জ': 967,
#  'ভোটে': 968,
#  'প্রশিক্ষণ': 969,
#  'ব্যাটে': 970,
#  'রংপুরের': 971,
#  'ছাত্রের': 972,
#  'নির্বাহী': 973,
#  'ঢুকে': 974,
#  'জাপানে': 975,
#  'রাজশাহীর': 976,
#  'যুক্তরাজ্য': 977,
#  'কঠিন': 978,
#  'ছাত্রী': 979,
#  'কৃষকের': 980,
#  'সুন্দরবনে': 981,
#  'বল': 982,
#  'টেস্ট': 983,
#  'শীর্ষ': 984,
#  'সোমবার': 985,
#  'দর': 986,
#  'প্রত্যাহারের': 987,
#  'বরাদ্দ': 988,
#  'সহিংসতার': 989,
#  'পদে': 990,
#  '২৮': 991,
#  'রানের': 992,
#  'স্মার্ট': 993,
#  'হরতালে': 994,
#  'আত্মবিশ্বাসী': 995,
#  'কিশোর': 996,
#  'বাড়তি': 997,
#  'সমাধান': 998,
#  'বিএনপিকে': 999,
#  'দুজন': 1000,
#  ...}

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim*2,))
decoder_state_input_c = Input(shape=(latent_dim*2,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim*2))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
#Function defining the implementation of inference process
def decode_sequence(input_seq):
    # Encode the input sequence to get the initial states for the decoder
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    # print('input_seq: {}, e_out: {} '.format(input_seq,e_out))
    

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    count = 0
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        # print("sampled_token:",sampled_token)
        # print("sampled_token_index:",sampled_token_index)
        # print("decoded_sent:",decoded_sentence)
        if(sampled_token!='end' and sampled_token not in decoded_sentence.split()):
            decoded_sentence += ' '+sampled_token

            # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1) or count == 3):
            stop_condition = True

        if(sampled_token in decoded_sentence.split()) :
            count = count + 1

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index
        # stop_condition = True
        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
#Functions to convert an integer sequence to a word sequence for summary as well as reviews 
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
# seq2summary(y_val[i])

# %%
#Summaries generated by the model
for i in range(100, 120):
  print("Article:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Article: এবারের গোল্ডেন আসর জর্জ ক্লুনির ছবি নিষিদ্ধ ঘোষিত ইরানি পত্রিকা ফরাসি পত্রিকা শার্লি এবদুতে সন্ত্রাসী হামলার প্রতিবাদে এবারের গোল্ডেন আসরে শার্লি শার্লি লেখা ব্যাজ ক্লুনি ছবি কারণেই ইরানের আদালত নিষিদ্ধ নামের
# Original summary: ছবি ছেপে নিষিদ্ধ ইরানি পত্রিকা
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  এফবিআই কারদাশিয়ানের অফ
#
#
# Article: নারায়ণগঞ্জের ফতুল্লায় পেট্রোল বোমার ব্যাগ ফেলে পালানোর সময় মোটরসাইকেল আরোহী যুবককে আটক নারী এএসআই
# Original summary: বোমাবাজকে নারী এএসআই
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  গাজীপুরে অটোরিকশা খুন মোটরসাইকেল
#
#
# Article: বিএনপি জোটের লাগাতার অবরোধের একুশে ফেব্রুয়ারিতে চট্টগ্রামের খুলশী থানার স্কুল মার্কেটের দোকানে হাতবোমা বিস্ফোরণে আহত
# Original summary: চট্টগ্রামে হাতবোমা বিস্ফোরণে আহত ২
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  চট্টগ্রামে হাতবোমায় বিস্ফোরণ
#
#
# Article: অর্থ বছরের প্রস্তাবিত বাজেটকে অভিনন্দন জানিয়েছেন যুক্তরাষ্ট্রে বসবাসরত মুক্তিযোদ্ধারা
# Original summary: বিড়ির শুল্কে বৈষম্য লক্ষ্মীপুরে মানববন্ধন
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  বাংলাদেশে আসছেন থাকতে পাঠাচ্ছে
#
#
# Article: সালের মার্চ খেলেছিলেন সবশেষ ওয়ানডে মোশাররফ হোসেনের স্মৃতির পাতায় জমে কথা বাঁহাতি স্পিনার পেলেন অভিজ্ঞতা সাড়ে খেলতে নামলেন ওয়ানডে ম্যাচ
# Original summary: ফারুককে ছাড়িয়ে মোশাররফ
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  বিশ্বকাপে একাদশে মাহমুদুল্লাহ
#
#
# Article: কেক তৈরির পদ্ধতি
# Original summary: তৈরি
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  নেত্রকোণায়
#
#
# Article: পুঁজিবাজার নিয়ন্ত্রক সংস্থা সিকিউরিটিজ অ্যান্ড এক্সচেঞ্জ বিএসইসি সরকারি কোষাগারে লাখ টাকা জমা
# Original summary: সরকারের বিএসইসির ৬১ টাকা
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  নয়টি ফান্ডের কমেছে লভ্যাংশ
#
#
# Article: ঢাকায় বিশ্ববিদ্যালয় ছাত্রীকে ধর্ষণের মামলার প্রধান আসামি আপন জুয়েলার্সের মালিকের ছেলে সাফাত আহমেদকে গ্রেপ্তারে গুলশানের বাসায় অভিযান চালিয়েছে পুলিশ
# Original summary: সাফাতের বাবা মিথ্যা পুলিশ
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  সাংবাদিক খুন আটক ২
#
#
# Article: লেখক বাংলাদেশে জাদুঘর আন্দোলনের পথিকৃৎ এনামুল হকের জন্মদিন উদযাপিত
# Original summary: এনামুল হকের জন্মদিন উদযাপন
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  লন্ডনে নজরুল জন্মজয়ন্তীতে স্মৃতি
#
#
# Article: শুনতে অদ্ভুত লাগলেও মাঝে মাঝে এসব অস্বাভাবিক খাবার উপাদানের স্বাস্থ্য চুল ত্বক ভালো রাখতে সাহায্য
# Original summary: আজব
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  পেটের ব্যবহারের রাখতে
#
#
# Article: অনূর্ধ্ব বিশ্বকাপে দলকে যথাযথ নিরাপত্তা দিয়েছিল বাংলাদেশ বিসিবির গণমাধ্যম যোগাযোগ কমিটির প্রধান জালাল ইউনুস তুলনায় ইংল্যান্ডকে নিরাপত্তা কাজটা সহজ
# Original summary: ইংল্যান্ডকে নিরাপত্তা অপেক্ষাকৃত সহজ বিসিবি
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  ভারতের আসছেন দল
#
#
# Article: ফেনীতে ট্রাকচাপায় নির্মাণ শ্রমিক নিহত
# Original summary: ফেনীতে ট্রাকচাপায় নির্মাণ শ্রমিক নিহত
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  ফরিদপুরে দুর্ঘটনায় প্রকৌশলীর মৃত্যু
#
#
# Article: সিলেটে ছাত্রলীগকর্মীর হামলায় সঙ্কটাপন্ন কলেজছাত্রী খাদিজা বেগম নার্গিসকে তোলা সেলফি ফেইসবুকে সমালোচিত যুব মহিলা লীগের নেত্রীর একজন দুঃখ প্রকাশ আরেকজন প্রকাশ ক্ষোভ
# Original summary: খাদিজার সেলফি নেত্রীর দুঃখ প্রকাশ আরেকজনের ক্ষোভ
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  সাংবাদিক সমাহিত
#
#
# Article: তথ্য প্রযুক্তি বিভাগের আইসিটি স্টার্টআপ চ্যালেঞ্জ জিতল তরুণদের উদ্ভাবনী প্রকল্প
# Original summary: স্টার্টআপ চ্যালেঞ্জ জিতল ২০ উদ্ভাবনী প্রকল্প
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  অনলাইন সেবা গুগলের
#
#
# Article: রাজধানীতে নাশকতায় জড়িত অভিযোগে বিএনপি জামায়াতে ইসলামীর নেতাকর্মীকে গ্রেপ্তার পুলিশ
# Original summary: রাজধানীতে নাশকতায় গ্রেপ্তার ৩২
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  চট্টগ্রামে বিএনপিজামায়াতের ৭৬ গ্রেপ্তার
#
#
# Article: হরতালঅবরোধে হাতেনাতে ধরিয়ে দিলে নগদ লাখ টাকা পুরস্কার মাগুরা জেলা পুলিশ
# Original summary: ধরিয়ে মাগুরায় পুলিশের মাইকিং
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দশ টাকার চাল বিতরণে
#
#
# Article: একুশে অগাস্ট গ্রেনেড হামলা মামলায় আসামিদের আত্মপক্ষ সমর্থনের শুনানি
# Original summary: ২১ অগাস্ট মামলার আসামিদের আত্মপক্ষ সমর্থন
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  তারেককে গ্রেপ্তারে গ্রেপ্তারের
#
#
# Article: গাজীপুরের শ্রীপুরে দোকান পোশাক শ্রমিকের লাশ উদ্ধার পুলিশ
# Original summary: গাজীপুরে পোশাক শ্রমিকের লাশ উদ্ধার
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  আশুলিয়ায় পুকুরে মিলল কর্মচারীর
#
#
# Article: যথাযোগ্য মর্যাদা ধর্মীয় পূর্ব লন্ডনে সরস্বতী পূজা
# Original summary: পূর্ব লন্ডনে পূজা অনুষ্ঠিত
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  পর্তুগালে প্রবাসী প্রবাসীদের জন্মদিন
#
#
# Article: লিগ শিরোপা পুনরুদ্ধারের পথে জয়ের ধারা রাখতে কঠিন লড়াইয়ের মুখে পড়তে বার্সেলোনাকে এবারের প্রতিপক্ষ ভিয়ারিয়াল টানা ম্যাচ অপরাজিত
# Original summary: বার্সার ভিয়ারিয়াল বাধা
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  রোমাঞ্চকর হারাতে হারাল

# %%
print("Article:",seq2text(x_val[113]))
print("Original summary:",seq2summary(y_val[113]))
print("Predicted summary:",decode_sequence(x_val[113].reshape(1,max_len_text)))
# Out:
# Article: তথ্য প্রযুক্তি বিভাগের আইসিটি স্টার্টআপ চ্যালেঞ্জ জিতল তরুণদের উদ্ভাবনী প্রকল্প
# Original summary: স্টার্টআপ চ্যালেঞ্জ জিতল ২০ উদ্ভাবনী প্রকল্প
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  অনলাইন সেবা গুগলের

# %%
#BLEU Score of Training set
#n-gram individual BLEU
from nltk.translate.bleu_score import sentence_bleu
one_gram = []
two_gram = []
for i in range(0,100):
  if(i==21):
    continue
  print(i)
  reference = seq2summary(y_val[i])
  candidate = decode_sequence(x_val[i].reshape(1, max_len_text))
  one_gram.append(sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)))
  two_gram.append(sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0)))
# reference = seq2summary(y_val[1])
# candidate = decode_sequence(x_val[1].reshape(1, max_len_text))

print(reference)
print(candidate)
# Out:
# 0
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 3
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 4
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 5
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 6
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 7
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 9
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 10
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 11
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 12
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 13
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 14
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 15
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 16
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 17
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 18
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 19
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 20
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 22
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 23
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 24
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 25
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 26
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 27
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 28
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 29
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 30
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 31
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 32
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 33
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 34
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 35
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 36
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 37
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 38
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 39
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 40
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 41
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 42
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 43
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 44
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 45
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 46
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 47
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 48
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 49
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 50
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 51
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 52
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 53
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 54
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 55
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 56
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 57
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 58
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 59
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 60
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 61
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 62
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 63
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 64
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 65
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 66
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 67
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 68
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 69
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 70
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 71
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 72
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 73
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 74
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 75
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 76
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 77
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 78
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 79
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 80
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 81
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 82
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 83
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 84
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 85
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 86
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 87
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 88
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 89
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 90
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 91
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 92
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 93
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 94
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 95
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 96
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 97
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 98
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 99
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# দর্শক ম্যাচ জিতে ফাইনালে ঘানা
#  কঙ্গোকে হারিয়ে ফাইনালে কোত

# %%
print("Individual 1-gram: ", np.average(one_gram))
# Out:
# Individual 1-gram:  0.4179494413414376

# %%
# !pip install rouge
from rouge import Rouge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
# Evaluate summarization using ROUGE metrics
def evaluate_summarization(reference_summary, generated_summary):
    rouge = Rouge()
    scores = rouge.get_scores(generated_summary, reference_summary)
    return scores[0]['rouge-1']['f'], scores[0]['rouge-2']['f'], scores[0]['rouge-l']['f']

# %%
f1_score_1 = []
f1_score_2 = []
f1_score_l = []
for i in range(0,100):
  if(i==21):
    continue
  print(i)
  reference = seq2summary(y_val[i])
  candidate = decode_sequence(x_val[i].reshape(1, max_len_text))
  score_1, score_2, score_l = evaluate_summarization(reference, candidate)
  f1_score_1.append(score_1)
  f1_score_2.append(score_2)
  f1_score_l.append(score_l)


print("ROUGE-1 F1-score:", np.average(f1_score_1))
print("ROUGE-2 F1-score:", np.average(f1_score_2))
print("ROUGE-L F1-score:", np.average(f1_score_l))
# Out:
# 0
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 3
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 4
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 5
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 6
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 7
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 9
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 10
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 11
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 12
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 13
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 14
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 15
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 16
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 17
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 18
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 19
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 20
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 22
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 23
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 24
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 25
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 26
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 27
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 28
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 29
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 88ms/step
# 30
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 32
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 68ms/step
# 33
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 34
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 35
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 36
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 37
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 89ms/step
# 38
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 194ms/step
# 39
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 109ms/step
# 40
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 87ms/step
# 41
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 42
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 81ms/step
# 43
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 41ms/step
# 44
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 44ms/step
# 45
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 46
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 84ms/step
# 47
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 109ms/step
# 48
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 175ms/step
# 49
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 225ms/step
# 50
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 103ms/step
# 51
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 96ms/step
# 52
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 56ms/step
# 53
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 58ms/step
# 54
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 55
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 20ms/step
# 56
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 57
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 58
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 59
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 60
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 61
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 62
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 63
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 64
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 65
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 66
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 67
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 68
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 69
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 70
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 71
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 72
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 73
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 74
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 75
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 76
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 77
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 78
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 79
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 80
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 81
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 82
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 83
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 84
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 85
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 86
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 87
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 88
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 89
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 90
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 91
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 92
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 93
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 94
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 95
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 96
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 97
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 98
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 99
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ROUGE-1 F1-score: 0.13045971821260396
# ROUGE-2 F1-score: 0.019913419720062303
# ROUGE-L F1-score: 0.12204220979509556
